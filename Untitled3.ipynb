# %% [markdown]
# <a href="https://colab.research.google.com/github/daveo3267/Content/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dave = pd.read_excel('/content/accident.xlsx')
print("Shape of the dataset:",dave.shape)
dave.head(8)
# Out:
# Shape of the dataset: (7, 9)
#   Accident date  Number of Casualities Weather condition Traffic signals  \
# 0    2020-10-06                      6             Rainy             Yes
# 1    2021-09-12                      4             Foggy              No
# 2    2022-09-01                      1             Clear              No
# 3    2023-10-05                      7             Foggy             Yes
# 4    2020-01-04                      8             Foggy              No
# 5    2022-11-11                      2             clear             Yes
# 6    2023-05-12                     10             Rainy              No
#
#   Drugs Usage Pedestrians present Seatbelt usage  Speed limit  no of overload
# 0         Yes                 Yes             No        60.13               7
# 1          No                 Yes             No        20.22               5
# 2         Yes                  No            Yes        61.44               3
# ...

# %%
import pandas as pd
dave=pd.read_excel('/content/accident.xlsx')
data=dave.loc[:,['Number of Casualities','no of overload']]
data.head(8)
# Out:
#    Number of Casualities  no of overload
# 0                      6               7
# 1                      4               5
# 2                      1               3
# 3                      7               8
# 4                      8               9
# 5                      2               4
# 6                     10              12

# %%
import pandas as pd
import matplotlib.pyplot as plt
dave=pd.read_excel('/content/accident.xlsx')
dave.plot(x='Number of Casualities',y='no of overload',style='o')
plt.xlabel('Number of Casualities')
plt.ylabel('no of overload')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
dave=pd.read_excel('/content/accident.xlsx')
X=dave[['Number of Casualities']]
y=dave['no of overload']
regressor=LinearRegression()
regressor.fit(X, y)
dave.plot(x='Number of Casualities',y='no of overload',style='o',label='Data Points')
plt.plot(X, regressor.predict(X), color='red',linewidth=3, label='Regression line')
plt.xlabel('Number of Casualities')
plt.ylabel('no of overload')
plt.legend()
plt.show()

# %%
import pandas as pd
dave=pd.read_excel('/content/accident.xlsx')
x=pd.DataFrame(data['Number of Casualities'])
y=pd.DataFrame(data['no of overload'])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
dave=pd.read_excel('/content/accident.xlsx')
x=pd.DataFrame(data['Number of Casualities'])
y=pd.DataFrame(data['no of overload'])
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5, 1)
# (2, 1)
# (5, 1)
# (2, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# [1.99137931]

# %%
print(regressor.coef_)
# Out:
# [[0.85344828]]

# %%
y_pred=regressor.predict(X_test)
y_pred
# Out:
# array([[10.52586207],
#        [ 2.84482759]])

# %%
y_test.head(8)
# Out:
#    no of overload
# 6              12
# 2               3

# %%
from sklearn import metrics
import numpy as np
mae=metrics.mean_absolute_error(y_test, y_pred)
mse=metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) # RMSE is the square root of MSE
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): 0.8146551724137931
# Mean Squared Error (MSE): 1.0985805588585036
# Root Mean Squared Error (RMSE): 1.0481319377151446

# %%
import joblib
import pickle
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x, y)
joblib.dump(model, 'linear regression_model.pk1')
with open('linear_regression_model.pkl', 'wb') as file:
  pickle.dump(model, file)

# %%
import joblib
import numpy as np
import pandas as pd
new_X = np.array([4, 6, 8, 10, 12]).reshape(-1, 1)
model = joblib.load('linear regression_model.pk1')
predictions=model.predict(new_X)
new_data = pd.DataFrame({'X': new_X. flatten(), 'Predicted_Y': predictions. flatten()})
print(new_data)
# Out:
#     X  Predicted_Y
# 0   4     5.502242
# 1   6     7.399103
# 2   8     9.295964
# 3  10    11.192825
# 4  12    13.089686
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
